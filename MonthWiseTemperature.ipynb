# %% [markdown]
# <a href="https://colab.research.google.com/github/hecker03/MLearning-DeepL/blob/main/MonthWiseTemperature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing the Dataset**

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("venky73/temperatures-of-india")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'temperatures-of-india' dataset.
# Path to dataset files: /kaggle/input/temperatures-of-india

# %%
import pandas as pd
df = pd.read_csv(f"{path}/temperatures.csv")
df.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %% [markdown]
# # **Data Preprocessing**

# %%
df.shape
# Out:
# (117, 18)

# %%
#Missing values
values = list(df.isnull().sum())
if(values.count(0) == len(values)):
  print("No Null Values")
else :
  print(values)
# Out:
# No Null Values

# %%
df.dtypes
# Out:
# YEAR         int64
# JAN        float64
# FEB        float64
# MAR        float64
# APR        float64
# MAY        float64
# JUN        float64
# JUL        float64
# AUG        float64
# SEP        float64
# OCT        float64
# NOV        float64
# DEC        float64
# ANNUAL     float64
# JAN-FEB    float64
# MAR-MAY    float64
# JUN-SEP    float64
# OCT-DEC    float64
# dtype: object

# %%
df.describe()
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   117.000000  117.000000  117.000000  117.000000  117.000000
# mean   1959.000000   23.687436   25.597863   29.085983   31.975812
# std      33.919021    0.834588    1.150757    1.068451    0.889478
# min    1901.000000   22.000000   22.830000   26.680000   30.010000
# 25%    1930.000000   23.100000   24.780000   28.370000   31.460000
# 50%    1959.000000   23.680000   25.480000   29.040000   31.950000
# 75%    1988.000000   24.180000   26.310000   29.610000   32.420000
# max    2017.000000   26.940000   29.720000   32.620000   35.380000
#
#               MAY         JUN         JUL         AUG         SEP         OCT  \
# count  117.000000  117.000000  117.000000  117.000000  117.000000  117.000000
# mean    33.565299   32.774274   31.035897   30.507692   30.486752   29.766581
# std      0.724905    0.633132    0.468818    0.476312    0.544295    0.705492
# ...

# %% [markdown]
# ## **Feature Engineering/Scaling**

# %%
#not required
df_long = df.melt(id_vars=['YEAR'],
                  value_vars=['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC'],
                  var_name='MONTH',
                  value_name='TEMP')
month_map = {'JAN':1, 'FEB':2, 'MAR':3, 'APR':4, 'MAY':5, 'JUN':6,
             'JUL':7, 'AUG':8, 'SEP':9, 'OCT':10, 'NOV':11, 'DEC':12}
df_long['MONTH_NUM'] = df_long['MONTH'].map(month_map)

# %% [markdown]
# ## **Apply the Model**

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df_long[['MONTH_NUM']]  # or [['YEAR', 'MONTH_NUM']] for time-aware model
y = df_long['TEMP']

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Predict for all months
month_range = pd.DataFrame({'MONTH_NUM': range(1, 13)})
predictions = model.predict(month_range)

# %% [markdown]
# ## **Evaluation of the Model**

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)

# %%
print(f"MSE: {mse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"R² Score: {r2:.4f}")

# %% [markdown]
# ## **Ploting the model**

# %%
import matplotlib.pyplot as plt

plt.plot(month_range['MONTH_NUM'], predictions, marker='o')
plt.xticks(range(1,13), list(month_map.keys()), rotation=45)
plt.xlabel('Month')
plt.ylabel('Predicted Temperature')
plt.title('Month-wise Temperature Prediction')
plt.grid(True)
plt.show()
